# %%
pip install pandas-profiling[notebook]
# Out:
# Requirement already satisfied: pandas-profiling[notebook] in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (1.1.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (1.7.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (1.1.5)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (3.5.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (1.9.1)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (3.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (1.21.6)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (0.5.1)
# Requirement already satisfied: phik>=0.11.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (0.12.2)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (2.27.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (4.64.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (0.11.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (1.8)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (7.0.6)
# Requirement already satisfied: jupyter-core>=4.6.3 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas-profiling[notebook]) (4.9.1)
# Collecting ipywidgets>=7.5.1
#   Using cached ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (2.6.3)
# Requirement already satisfied: imagehash in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (9.1.0)
# Note: you may need to restart the kernel to use updated packages.Collecting ipython-genutils~=0.2.0
#   error: subprocess-exited-with-error
#
#   × Building wheel for pywinpty (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [52 lines of output]
#       Running `maturin pep517 build-wheel -i c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\python.exe --compatibility off`
#          Compiling autocfg v1.1.0
#          Compiling target-lexicon v0.12.4
#          Compiling libc v0.2.126
#          Compiling proc-macro2 v1.0.39
#          Compiling windows_x86_64_msvc v0.29.0
#          Compiling unicode-ident v1.0.0
#          Compiling once_cell v1.12.0
#          Compiling syn v1.0.95
#          Compiling windows_x86_64_msvc v0.36.1
#          Compiling either v1.6.1
#          Compiling parking_lot_core v0.9.3
#          Compiling lazy_static v1.4.0
#          Compiling scopeguard v1.1.0
#          Compiling smallvec v1.8.0
#          Compiling cfg-if v1.0.0
#          Compiling indoc v1.0.6
#          Compiling bitflags v1.3.2
#          Compiling unindent v0.1.9
#          Compiling num-traits v0.2.15
#          Compiling lock_api v0.4.7
#          Compiling windows v0.29.0
#          Compiling windows-sys v0.36.1
#          Compiling which v4.2.5
#          Compiling quote v1.0.18
#          Compiling pyo3-build-config v0.16.5
#          Compiling parking_lot v0.12.1
#          Compiling winpty-rs v0.3.6
#          Compiling pyo3-ffi v0.16.5
#          Compiling pyo3 v0.16.5
#       error: failed to run custom build command for `pyo3-ffi v0.16.5`
#
#       Caused by:
#         process didn't exit successfully: `C:\Users\YINMAN~1\AppData\Local\Temp\pip-install-h1jvqy2u\pywinpty_ebc30a3a48d24d87be280cae31fe1af4\target\release\build\pyo3-ffi-2f6868c5b62b1434\build-script-build` (exit code: 1)
#         --- stdout
#         cargo:rerun-if-env-changed=PYO3_CROSS
#         cargo:rerun-if-env-changed=PYO3_CROSS_LIB_DIR
#         cargo:rerun-if-env-changed=PYO3_CROSS_PYTHON_VERSION
#         cargo:rerun-if-env-changed=PYO3_CROSS_PYTHON_IMPLEMENTATION
#         cargo:rerun-if-env-changed=PYO3_PRINT_CONFIG
#
#         --- stderr
#         error: your Rust target architecture (64-bit) does not match your python interpreter (32-bit)
#       warning: build failed, waiting for other jobs to finish...
#       ðŸ’¥ maturin failed
#         Caused by: Failed to build a native library through cargo
#         Caused by: Cargo build finished with "exit code: 101": `cargo rustc --manifest-path Cargo.toml --message-format json --release --lib --`
#       ðŸ“¦ Including license file "LICENSE.txt"
#       ðŸ\x8d¹ Building a mixed python/rust project
#       ðŸ”— Found pyo3 bindings
#       ðŸ\x90\x8d Found CPython 3.7 at c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\python.exe
#       Error: command ['maturin', 'pep517', 'build-wheel', '-i', 'c:\\Users\\Yin Man Li\\AppData\\Local\\Programs\\Python\\Python37-32\\python.exe', '--compatibility', 'off'] returned non-zero exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pywinpty
# ERROR: Could not build wheels for pywinpty, which is required to install pyproject.toml-based projects
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting widgetsnbextension~=3.6.0
#   Using cached widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.3.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (7.29.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Using cached jupyterlab_widgets-1.1.0-py3-none-any.whl (245 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jinja2>=2.11.1->pandas-profiling[notebook]) (2.1.1)
# Requirement already satisfied: tornado>=4.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (1.5.1)
# Requirement already satisfied: entrypoints in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (0.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (302)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (4.31.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (21.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[notebook]) (2022.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from pydantic>=1.8.1->pandas-profiling[notebook]) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2.0.12)
# Requirement already satisfied: colorama in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from tqdm>=4.48.2->pandas-profiling[notebook]) (0.4.4)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.3)
# Requirement already satisfied: argcomplete>=1.12.3 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.12.3)
# Requirement already satisfied: importlib-metadata<5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.8.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (39.0.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.0)
# Requirement already satisfied: pygments in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.22)
# Requirement already satisfied: decorator in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.0)
# Requirement already satisfied: pickleshare in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: backcall in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=5.3.4->pandas-profiling[notebook]) (1.16.0)
# Collecting notebook>=4.4.1
#   Using cached notebook-6.4.11-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: PyWavelets in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling[notebook]) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from importlib-metadata<5->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.7.1)
# Collecting prometheus-client
#   Using cached prometheus_client-0.14.1-py3-none-any.whl (59 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.15.0-py3-none-any.whl (16 kB)
# Collecting Send2Trash>=1.8.0
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting argon2-cffi
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: nbconvert>=5 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.5.0)
# Requirement already satisfied: wcwidth in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.11.1)
# Requirement already satisfied: defusedxml in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.4)
# Requirement already satisfied: tinycss2 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.1.1)
# Requirement already satisfied: bleach in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.0.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.6.0)
# Collecting pywinpty>=1.1.0
#   Using cached pywinpty-2.0.5.tar.gz (23 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win32.whl (27 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.0-cp37-cp37m-win32.whl (166 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\yin man li\appdata\local\programs\python\python37-32\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.5.1)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: pywinpty
#   Building wheel for pywinpty (pyproject.toml): started
#   Building wheel for pywinpty (pyproject.toml): finished with status 'error'
# Failed to build pywinpty

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %%
ad =  pd.read_csv('dataset.csv')

# %%
profile = ProfileReport(ad, title="Alzheimer Exploratory Data Analysis")

# %%
profile.to_file(output_file="EDA.html")
# Out:
# Summarize dataset: 100%|██████████| 79/79 [00:14<00:00,  5.56it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.74s/it]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\YINMAN~1\AppData\Local\Temp/ipykernel_3580/2130615311.py in <module>
# ----> 1 profile.to_widgets()
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\profile_report.py in to_widgets(self)
#     412         from IPython.core.display import display
#     413
# --> 414         display(self.widgets)
#     415
#     416     def _repr_html_(self) -> None:
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\profile_report.py in widgets(self)
#     195     def widgets(self) -> Renderable:
#     196         if self._widgets is None:
# --> 197             self._widgets = self._render_widgets()
#     198         return self._widgets
#     199
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\profile_report.py in _render_widgets(self)
#     321             leave=False,
#     322         ) as pbar:
# --> 323             widgets = WidgetReport(copy.deepcopy(report)).render()
#     324             pbar.update()
#     325         return widgets
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\report\presentation\flavours\flavours.py in WidgetReport(structure)
#     137
#     138 def WidgetReport(structure: Root) -> Root:
# --> 139     mapping = get_widget_renderable_mapping()
#     140     apply_renderable_mapping(mapping, structure, flavour=WidgetReport)
#     141     return structure
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\report\presentation\flavours\flavours.py in get_widget_renderable_mapping()
#     101         VariableInfo,
#     102     )
# --> 103     from pandas_profiling.report.presentation.flavours.widget import (
#     104         WidgetAlerts,
#     105         WidgetCollapse,
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\__init__.py in <module>
# ----> 1 from pandas_profiling.report.presentation.flavours.widget.alerts import WidgetAlerts
#       2 from pandas_profiling.report.presentation.flavours.widget.collapse import WidgetCollapse
#       3 from pandas_profiling.report.presentation.flavours.widget.container import (
#       4     WidgetContainer,
#       5 )
#
# c:\Users\Yin Man Li\AppData\Local\Programs\Python\Python37-32\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\alerts.py in <module>
#       1 from typing import List
#       2
# ----> 3 from ipywidgets import HTML, Button, widgets
#       4
#       5 from pandas_profiling.report.presentation.core import Alerts
#
# ModuleNotFoundError: No module named 'ipywidgets'
